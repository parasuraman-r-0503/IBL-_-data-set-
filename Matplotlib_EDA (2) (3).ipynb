# %% [markdown]
# # Import Necessary Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
df=pd.read_csv('ipl_summary.csv')
df.head()
# Out:
#          team1 team2       winner   margin   matchDate match_id  \
# 0  Super Kings   KKR  Super Kings  27 runs  2021-10-15  T203817
# 1  Super Kings   KKR  Super Kings  27 runs  2021-10-15  T203817
# 2  Super Kings   KKR  Super Kings  27 runs  2021-10-15  T203817
# 3  Super Kings   KKR  Super Kings  27 runs  2021-10-15  T203817
# 4  Super Kings   KKR  Super Kings  27 runs  2021-10-15  T203817
#
#                 match  teamInnings  battingPos     batsmanName out/not_out  \
# 0  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad         out
# 1  Super Kings Vs KKR  Super Kings           2    FafduPlessis         out
# 2  Super Kings Vs KKR  Super Kings           3    RobinUthappa         out
# 3  Super Kings Vs KKR  Super Kings           4        MoeenAli     not_out
# 4  Super Kings Vs KKR          KKR           1     ShubmanGill         out
#
#    runs  balls  4s  6s      SR  season
# 0    32     27   3   1  118.51    2021
# 1    86     59   7   3  145.76    2021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3256 entries, 0 to 3255
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   team1        3256 non-null   object
#  1   team2        3256 non-null   object
#  2   winner       3256 non-null   object
#  3   margin       3256 non-null   object
#  4   matchDate    3256 non-null   object
#  5   match_id     3256 non-null   object
#  6   match        3256 non-null   object
#  7   teamInnings  3256 non-null   object
#  8   battingPos   3256 non-null   int64
#  9   batsmanName  3256 non-null   object
#  10  out/not_out  3256 non-null   object
#  11  runs         3256 non-null   int64
#  12  balls        3256 non-null   int64
#  13  4s           3256 non-null   int64
#  14  6s           3256 non-null   int64
#  15  SR           3256 non-null   object
#  16  season       3256 non-null   int64
# dtypes: int64(6), object(11)
# memory usage: 432.6+ KB

# %%
df[df['SR']=='-']
# Out:
#              team1         team2        winner      margin   matchDate  \
# 14     Super Kings           KKR   Super Kings     27 runs  2021-10-15
# 30        Capitals           KKR           KKR   3 wickets  2021-10-13
# 39             RCB           KKR           KKR   4 wickets  2021-10-11
# 62        Capitals   Super Kings   Super Kings   4 wickets  2021-10-10
# 84          Mumbai     Sunrisers        Mumbai     42 runs  2021-10-08
# 195            RCB  Punjab Kings           RCB      6 runs  2021-10-03
# 249            KKR  Punjab Kings  Punjab Kings   5 wickets  2021-10-01
# 312       Capitals           KKR           KKR   3 wickets  2021-09-28
# 370   Punjab Kings     Sunrisers  Punjab Kings      5 runs  2021-09-25
# 446         Royals  Punjab Kings        Royals      2 runs  2021-09-21
# 466            RCB           KKR           KKR   9 wickets  2021-09-20
# 527    Super Kings        Mumbai        Mumbai   4 wickets  2021-05-01
# ...

# %%
df.replace({
    'SR':'-'
} ,0,inplace=True)

# %%
df['SR']=df['SR'].apply(float)

# %%
df['SR'].dtype
# Out:
# dtype('float64')

# %%
df['season'].value_counts()
# Out:
# season
# 2022    1176
# 2023    1161
# 2021     919
# Name: count, dtype: int64

# %%
df['matchDate']=pd.to_datetime(df['matchDate'])

# %%
df_2=df.select_dtypes(include=['int64','float64'])
df_2.head(1)
# Out:
#    battingPos  runs  balls  4s  6s      SR  season
# 0           1    32     27   3   1  118.51    2021

# %%
df_1=df.select_dtypes(include='object')
df_1
# Out:
#             team1   team2       winner     margin match_id  \
# 0     Super Kings     KKR  Super Kings    27 runs  T203817
# 1     Super Kings     KKR  Super Kings    27 runs  T203817
# 2     Super Kings     KKR  Super Kings    27 runs  T203817
# 3     Super Kings     KKR  Super Kings    27 runs  T203817
# 4     Super Kings     KKR  Super Kings    27 runs  T203817
# ...           ...     ...          ...        ...      ...
# 3251  Super Kings  Titans       Titans  5 wickets  T201566
# 3252  Super Kings  Titans       Titans  5 wickets  T201566
# 3253  Super Kings  Titans       Titans  5 wickets  T201566
# 3254  Super Kings  Titans       Titans  5 wickets  T201566
# 3255  Super Kings  Titans       Titans  5 wickets  T201566
#
#                       match  teamInnings     batsmanName out/not_out
# 0        Super Kings Vs KKR  Super Kings  RuturajGaikwad         out
# 1        Super Kings Vs KKR  Super Kings    FafduPlessis         out
# ...

# %%
num_column=df_2.columns
categorical_columns=df_1.columns

# %%
num_column
# Out:
# Index(['battingPos', 'runs', 'balls', '4s', '6s', 'SR', 'season'], dtype='object')

# %%
categorical_columns
# Out:
# Index(['team1', 'team2', 'winner', 'margin', 'match_id', 'match',
#        'teamInnings', 'batsmanName', 'out/not_out'],
#       dtype='object')

# %%
df_numerical=df.select_dtypes(include=['float','int'])
df_numerical
# Out:
#       battingPos  runs  balls  4s  6s      SR  season
# 0              1    32     27   3   1  118.51    2021
# 1              2    86     59   7   3  145.76    2021
# 2              3    31     15   0   3  206.66    2021
# 3              4    37     20   2   3  185.00    2021
# 4              1    51     43   6   0  118.60    2021
# ...          ...   ...    ...  ..  ..     ...     ...
# 3251           3    22     17   3   0  129.41    2023
# 3252           4     8     11   0   0   72.72    2023
# 3253           5    27     21   2   1  128.57    2023
# 3254           6    15     14   1   1  107.14    2023
# 3255           7    10      3   1   1  333.33    2023
#
# [3256 rows x 7 columns]

# %%
df_categorical=df.select_dtypes(include='object')
df_categorical
# Out:
#             team1   team2       winner     margin match_id  \
# 0     Super Kings     KKR  Super Kings    27 runs  T203817
# 1     Super Kings     KKR  Super Kings    27 runs  T203817
# 2     Super Kings     KKR  Super Kings    27 runs  T203817
# 3     Super Kings     KKR  Super Kings    27 runs  T203817
# 4     Super Kings     KKR  Super Kings    27 runs  T203817
# ...           ...     ...          ...        ...      ...
# 3251  Super Kings  Titans       Titans  5 wickets  T201566
# 3252  Super Kings  Titans       Titans  5 wickets  T201566
# 3253  Super Kings  Titans       Titans  5 wickets  T201566
# 3254  Super Kings  Titans       Titans  5 wickets  T201566
# 3255  Super Kings  Titans       Titans  5 wickets  T201566
#
#                       match  teamInnings     batsmanName out/not_out
# 0        Super Kings Vs KKR  Super Kings  RuturajGaikwad         out
# 1        Super Kings Vs KKR  Super Kings    FafduPlessis         out
# ...

# %% [markdown]
# ## Univariate analysis

# %% [raw]
# Univariate analysis is a fundamental statistical technique that focuses on the examination of a single variable.
# This method is primarily used to summarize and describe the characteristics of that variable,
# providing insights into its distribution, central tendency, and variability

# %% [markdown]
# ### Histogram

# %% [markdown]
# #### A histplot (histogram plot) is used to visualize the distribution of a single numerical variable by grouping the data into bins and counting the frequency of observations in each bin. The height of each bar represents the number of data points (or frequency) in a given range

# %%
df_2.columns
# Out:
# Index(['battingPos', 'runs', 'balls', '4s', '6s', 'SR', 'season'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sn

from warnings import simplefilter
simplefilter(action='ignore')

# %%
a=10
b=20
print(a)
b
# Out:
# 10
# 20

# %%
plt.hist(df['runs'],bins=30,edgecolor='black',color='lightgreen')
plt.xlabel('runs')
# Out:
# Text(0.5, 0, 'runs')

# %%
df_numerical.columns
# Out:
# Index(['battingPos', 'runs', 'balls', '4s', '6s', 'SR', 'season'], dtype='object')

# %%
for i in df_numerical.columns:
    plt.hist(df[i],bins=30,edgecolor='black')
    plt.xlabel(i)
    plt.show()

# %%
a=10
b=20
a
b
# Out:
# 20

# %%
for i in num_column: # ['battingPos', 'runs', 'balls', '4s', '6s', 'SR', 'season']
    plt.hist(df[i],bins=30,color='lightblue',edgecolor='black')
    plt.title('Distribution')
    plt.xlabel(i)
    plt.ylabel('Distribution')
    plt.show()

# %% [markdown]
# ### Box plot

# %% [markdown]
# #### A box plot  is used to visualize the distribution of a numerical variable and summarize key statistics such as the median, quartiles, and potential outliers. It displays the spread and skewness of the data in a compact form, making it useful for comparing distributions between different categories

# %%
df_numerical.describe()
# Out:
#         battingPos         runs        balls           4s           6s  \
# count  3256.000000  3256.000000  3256.000000  3256.000000  3256.000000
# mean      4.776413    19.777641    14.690418     1.741708     0.872850
# std       2.716578    21.861925    13.515877     2.327012     1.425181
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     3.000000     4.000000     0.000000     0.000000
# 50%       4.000000    12.000000    10.000000     1.000000     0.000000
# 75%       7.000000    29.000000    21.000000     3.000000     1.000000
# max      11.000000   140.000000    70.000000    16.000000    10.000000
#
#                 SR       season
# count  3256.000000  3256.000000
# mean    112.223710  2022.074324
# std      71.432141     0.795922
# min       0.000000  2021.000000
# 25%      66.660000  2021.000000
# 50%     113.330000  2022.000000
# 75%     153.390000  2023.000000
# max     600.000000  2023.000000

# %%
for i in df_numerical.columns:
    sn.boxplot(data=df_numerical,x='runs')
    plt.show()

# %%
Q1=df['runs'].quantile(0.25)
Q3=df['runs'].quantile(0.75)

IQR=Q3-Q1 # Inter_quartile_range

lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)
print(Q1,Q3)
print(lower_bound,upper_bound)
# Out:
# 3.0 29.0
# -36.0 68.0

# %%
for i in df_2.columns:
    sn.boxplot(data=df_2, x=i,color='maroon',)
    plt.title(i)
    plt.show()

# %%
df.describe()
# Out:
#                            matchDate   battingPos         runs        balls  \
# count                           3256  3256.000000  3256.000000  3256.000000
# mean   2022-06-14 15:46:26.240786432     4.776413    19.777641    14.690418
# min              2021-04-09 00:00:00     1.000000     0.000000     0.000000
# 25%              2021-10-07 00:00:00     2.000000     3.000000     4.000000
# 50%              2022-05-01 00:00:00     4.000000    12.000000    10.000000
# 75%              2023-04-15 00:00:00     7.000000    29.000000    21.000000
# max              2023-05-26 00:00:00    11.000000   140.000000    70.000000
# std                              NaN     2.716578    21.861925    13.515877
#
#                 4s           6s           SR       season
# count  3256.000000  3256.000000  3256.000000  3256.000000
# mean      1.741708     0.872850   112.223710  2022.074324
# min       0.000000     0.000000     0.000000  2021.000000
# ...

# %%
Q1=df['battingPos'].quantile(0.25)
print(Q1)

Q3=df['battingPos'].quantile(0.75)
print(Q3)

IQR=Q3-Q1
print(IQR)
lower=Q1-(1.5*IQR)
print(lower)

upper=Q3+(1.5*IQR)
print(upper)
# Out:
# 2.0
# 7.0
# 5.0
# -5.5
# 14.5

# %%
Q1=df['runs'].quantile(0.25)
print(Q1)

Q3=df['runs'].quantile(0.75)
print(Q3)

IQR=Q3-Q1
lower=Q1-(1.5*IQR)
print(lower)

upper=Q3+(1.5*IQR)
print(upper)
# Out:
# 3.0
# 29.0
# -36.0
# 68.0

# %% [markdown]
# ### Categorical columns

# %% [markdown]
# ### count plot

# %% [markdown]
# #### A count plot is a type of bar plot that shows the counts of observations in each categorical bin. It provides a visual representation of the number of occurrences for each category in a dataset

# %%
df_1.columns
# Out:
# Index(['team1', 'team2', 'winner', 'margin', 'match_id', 'match',
#        'teamInnings', 'batsmanName', 'out/not_out'],
#       dtype='object')

# %%
# "deep", "muted", "pastel", "bright", "dark", "colorblind"

# %%
for i in df_1.columns:
    if i not in ['matchDate','match_id','match','batsmanName','margin']:
        plt.figure(figsize=(10, 5)) #(width,height)
        sn.countplot(data=df, x=i, palette='muted')
        plt.title(f'Frequency Distribution of {i}')
        plt.show()

# %% [markdown]
# ### Pie chart

# %% [markdown]
# #### A pie chart is a circular statistical graphic that is divided into slices to illustrate numerical proportions. Each slice represents a category's contribution to the total
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

# %%
df['team1'].value_counts()
# Out:
# team1
# Super Kings     456
# Punjab Kings    426
# RCB             414
# Royals          406
# Mumbai          310
# KKR             304
# Capitals        259
# Super Giants    237
# Titans          230
# Sunrisers       214
# Name: count, dtype: int64

# %%
for i in categorical_columns:
    if i not in ['batsmanName','match_id','matchDate','match','margin'] :
        plt.figure(figsize=(10, 6))
        counts=df[i].value_counts()
        plt.pie(counts,labels=counts.index,autopct='%.1f%%')
        plt.title(i)

# %% [markdown]
# ## Bi-Variate analysis

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# #### Shows correlation or trends between two continuous variables.

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df_2['balls'],df['runs'])
plt.title('Scatter Plot of Runs vs. Balls Faced')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Runs vs. Balls Faced')

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['balls'],df['runs'])
plt.title('Scatter Plot of Runs vs. Balls Faced')
plt.xlabel('Balls Faced')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
df.columns
# Out:
# Index(['team1', 'team2', 'winner', 'margin', 'matchDate', 'match_id', 'match',
#        'teamInnings', 'battingPos', 'batsmanName', 'out/not_out', 'runs',
#        'balls', '4s', '6s', 'SR', 'season'],
#       dtype='object')

# %%
pd.crosstab(columns=df['winner'],index=df['out/not_out'])
# Out:
# winner       Capitals  KKR  Mumbai  Punjab Kings  RCB  Royals  Sunrisers  \
# out/not_out
# not_out            78   77      72            68   89      77         46
# out               247  265     242           238  314     276        141
#
# winner       Super Giants  Super Kings  Titans
# out/not_out
# not_out                61           88      82
# out                   212          304     279

# %%
pd.crosstab(columns=df['team1'],index=df['out/not_out']).plot(kind='barh',figsize=(10,8))
# Out:
# <Axes: ylabel='out/not_out'>

# %%
df['runs'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['team1'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Line plot

# %% [markdown]
# #### Line charts are effective for visualizing trends over time or sequences,
# #### showing how data points are connected in a series.
# #### They are often used to display stock prices, temperature changes, or any time-series data.

# %%
df.groupby('season')['6s'].sum().reset_index()
# Out:
#    season    6s
# 0    2021   679
# 1    2022  1062
# 2    2023  1101

# %%
plt.figure(figsize=(10, 5))
average_runs = df.groupby('season')['6s'].sum().reset_index()
print(average_runs)


plt.plot(average_runs['season'].astype('str'),average_runs['6s'],marker='+')
plt.title('Total Sixes Over Seasons')
plt.xlabel('Season')
plt.ylabel('Sixes')
# Out:
#    season    6s
# 0    2021   679
# 1    2022  1062
# 2    2023  1101
# Text(0, 0.5, 'Sixes')

# %% [markdown]
# ## Multivariate analysis

# %% [markdown]
# #### Correlation is a statistical measure that indicates the strength and direction of a relationship between two variables.
# #### It is quantified using a correlation coefficient, which ranges from -1 to 1

# %%
df_2
# Out:
#       battingPos  runs  balls  4s  6s      SR  season
# 0              1    32     27   3   1  118.51    2021
# 1              2    86     59   7   3  145.76    2021
# 2              3    31     15   0   3  206.66    2021
# 3              4    37     20   2   3  185.00    2021
# 4              1    51     43   6   0  118.60    2021
# ...          ...   ...    ...  ..  ..     ...     ...
# 3251           3    22     17   3   0  129.41    2023
# 3252           4     8     11   0   0   72.72    2023
# 3253           5    27     21   2   1  128.57    2023
# 3254           6    15     14   1   1  107.14    2023
# 3255           7    10      3   1   1  333.33    2023
#
# [3256 rows x 7 columns]

# %%
df_2.corr()
# Out:
#             battingPos      runs     balls        4s        6s        SR  \
# battingPos    1.000000 -0.392249 -0.454688 -0.415670 -0.200567 -0.103760
# runs         -0.392249  1.000000  0.936873  0.862840  0.792364  0.515312
# balls        -0.454688  0.936873  1.000000  0.807391  0.633079  0.340975
# 4s           -0.415670  0.862840  0.807391  1.000000  0.473655  0.434729
# 6s           -0.200567  0.792364  0.633079  0.473655  1.000000  0.536682
# SR           -0.103760  0.515312  0.340975  0.434729  0.536682  1.000000
# season        0.013656  0.030647 -0.010141  0.032927  0.057084  0.062646
#
#               season
# battingPos  0.013656
# runs        0.030647
# balls      -0.010141
# 4s          0.032927
# 6s          0.057084
# SR          0.062646
# season      1.000000

# %%
correlation_matrix = df_2.corr()

plt.figure(figsize=(10, 6))
sn.heatmap(correlation_matrix,annot=True,fmt=".2g")
plt.title('Correlation Heatmap of Batting Statistics')
plt.show()
